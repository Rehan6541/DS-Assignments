# %% [markdown]
# Statistics

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv("crime_data.csv")
df.head()
# Out:
#          City  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df.shape
#chech the shape of data set
# Out:
# (50, 5)

# %%
df.columns
#check the columns of dataset
# Out:
# Index(['City', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
set(df['Murder'])
#continuous
# Out:
# {0.8,
#  2.1,
#  2.2,
#  2.6,
#  2.7,
#  3.2,
#  3.3,
#  3.4,
#  3.8,
#  4.0,
#  4.3,
#  4.4,
#  4.9,
#  5.3,
#  5.7,
#  5.9,
#  6.0,
#  6.3,
#  6.6,
#  6.8,
#  7.2,
#  7.3,
#  7.4,
#  7.9,
#  8.1,
#  8.5,
#  8.8,
#  9.0,
#  9.7,
#  10.0,
#  10.4,
#  11.1,
#  11.3,
#  11.4,
#  12.1,
#  12.2,
#  12.7,
#  13.0,
#  13.2,
#  14.4,
#  15.4,
#  16.1,
#  17.4}

# %%
df.Murder.describe()
# Out:
# count    50.00000
# mean      7.78800
# std       4.35551
# min       0.80000
# 25%       4.07500
# 50%       7.25000
# 75%      11.25000
# max      17.40000
# Name: Murder, dtype: float64

# %%
#plot a histogram
df['Murder'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#plot a density curve
df['Murder'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Murder'].skew()
#if value is 0 or nearabout 0 then alomost normally distributed
#if value beyond 1-->nearly right skewed
##if value beyond 3-->right skewed
#if value below -1-->nearly left skewed
##if value below -3-->left skewed
# Out:
# 0.3939564324470969

# %%
#draw boxplot to check outliers
df['Murder'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.Assault.describe()
# Out:
# count     50.000000
# mean     170.760000
# std       83.337661
# min       45.000000
# 25%      109.000000
# 50%      159.000000
# 75%      249.000000
# max      337.000000
# Name: Assault, dtype: float64

# %%
df['Assault'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Assault'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Assault'].skew()
# Out:
# 0.2344095905541752

# %%
df['Assault'].plot(kind='box')
# Out:
# <Axes: >

# %%
#check for null values
df['Murder'].isnull().sum()
# Out:
# 0

# %%
df['Assault'].isnull().sum()
# Out:
# 0

# %%
#find mean,median,std,var
df[['Murder','Assault']].mean()
# Out:
# Murder       7.788
# Assault    170.760
# dtype: float64

# %%
df[['Murder','Assault']].median()
# Out:
# Murder       7.25
# Assault    159.00
# dtype: float64

# %%
df[['Murder','Assault']].std()
# Out:
# Murder      4.355510
# Assault    83.337661
# dtype: float64

# %%
round(df[['Murder','Assault']].var(),2)
# Out:
# Murder       18.97
# Assault    6945.17
# dtype: float64

# %%
from scipy.stats import  iqr
#calculate the iqr
iqr(df[['Murder','Assault']],axis=0)
# Out:
# array([  7.175, 140.   ])

# %%
from scipy.stats import  skew,kurtosis
#chech the skewness and kurtosis

# %%
kurtosis(df['Assault'],fisher=False)
# Out:
# 1.930979948426923

# %%
kurtosis(df['Assault'],fisher=True)
# Out:
# -1.069020051573077

# %%
skew(df['Assault'])
# Out:
# 0.2273178665911123

# %%
#Z-score

# %%
from scipy.stats import zscore
#find z score
z=np.abs(zscore(df[['Murder','Assault']]))

# %%
z
# Out:
#       Murder   Assault
# 0   1.255179  0.790787
# 1   0.513019  1.118060
# 2   0.072361  1.493817
# 3   0.234708  0.233212
# 4   0.281093  1.275635
# 5   0.025976  0.402909
# 6   1.040880  0.736484
# 7   0.437875  0.815030
# 8   1.765415  1.990786
# 9   2.229265  0.487757
# 10  0.577030  1.512241
# 11  1.203228  0.615272
# 12  0.605789  0.948363
# 13  0.136372  0.700121
# 14  1.295998  1.391029
# 15  0.414682  0.675878
# 16  0.443441  0.748605
# 17  1.765415  0.948363
# 18  1.319191  1.063757
# 19  0.814521  1.566544
# 20  0.785763  0.263757
# 21  1.000062  1.021090
# 22  1.180036  1.197090
# 23  1.927762  1.069575
# 24  0.281093  0.087757
# 25  0.414682  0.748605
# 26  0.808955  0.833454
# 27  1.023254  0.984726
# 28  1.319191  1.378908
# 29  0.089987  0.142545
# 30  0.837714  1.384726
# 31  0.768136  1.008969
# 32  1.208794  2.015028
# 33  1.620693  1.524362
# 34  0.113180  0.615272
# 35  0.275527  0.239515
# 36  0.669800  0.142545
# 37  0.345105  0.784969
# 38  1.017688  0.039273
# ...

# %% [markdown]
# Data prep

# %%
import pandas as pd
df=pd.read_csv("crime_data.csv")
df.dtypes
# Out:
# City         object
# Murder      float64
# Assault       int64
# UrbanPop      int64
# Rape        float64
# dtype: object

# %%
#Murder,Rape  data type is float change it to int
df.Murder=df.Murder.astype(int)
df.Rape=df.Rape.astype(int)
df.dtypes
# Out:
# City        object
# Murder       int32
# Assault      int64
# UrbanPop     int64
# Rape         int32
# dtype: object

# %%
#Identify the duplicate
duplicate=df.duplicated()
#output of this function is single column
#if there is duplicate records output is true
#if there is no duplicate records output is false
#Series will be created
duplicate#all false
sum(duplicate)
#output will be 0
# Out:
# 0

# %%
#outliers treatement
sns.boxplot(df.Murder)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Assault)
#No outliers
# Out:
# <Axes: >
